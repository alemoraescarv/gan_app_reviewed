# %% [markdown]
# Test stable diffusion 1.5

# %%
# %pip install -q -U --pre triton
# %pip install -q accelerate==0.12.0 transformers ftfy bitsandbytes gradio natsort
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 69.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 83.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 117.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 10.9 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done

# %%
# %pip install -q accelerate==0.20.3
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 4.3 MB/s eta 0:00:00

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py

# %%
# !pip install git+https://github.com/huggingface/diffusers
# Out:
# Collecting git+https://github.com/huggingface/diffusers
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-9fn3lprx
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-9fn3lprx
#   Resolved https://github.com/huggingface/diffusers to commit 74d902eb59f873b6156621220937f8e2521dfdc0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (6.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (3.12.2)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (0.16.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (0.3.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.0.dev0) (9.4.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.0.dev0) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.0.dev0) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.0.dev0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.0.dev0) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.21.0.dev0) (23.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.21.0.dev0) (3.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.0.dev0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.21.0.dev0) (2023.7.22)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.21.0.dev0-py3-none-any.whl size=1344047 sha256=3e1c796646961cbbaabe242db8b5735e1a5397a0c91e01ae73aa1bc231e292e3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-co6l5v2y/wheels/f7/7d/99/d361489e5762e3464b3811bc629e94cf5bf5ef44dd5c3c4d52
# Successfully built diffusers
# Installing collected packages: diffusers
# Successfully installed diffusers-0.21.0.dev0

# %%
# !pwd
# Out:
# /content

# %%
#Setting env var to access Hugging Face
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %%
#download the model locally
#Using model runwayml/stable-diffusion-v1-5

from huggingface_hub import snapshot_download


local_dir = "./stable_diffusion_weights"

snapshot_download(
    "runwayml/stable-diffusion-v1-5",
    local_dir=local_dir,
    ignore_patterns=".gitattributes",
)
OUTPUT_DIR = "/content/" + local_dir
# !mkdir -p $OUTPUT_DIR
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_hf_folder.py:95: UserWarning: A token has been found in `/root/.huggingface/token`. This is the old path where tokens were stored. The new location is `/root/.cache/huggingface/token` which is configurable using `HF_HOME` environment variable. Your token has been copied to this new location. You can now safely delete the old token file manually or use `huggingface-cli logout`.
#   warnings.warn(
# Fetching 33 files:   0%|          | 0/33 [00:00<?, ?it/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading (…)_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading (…)7e196057f0/README.md:   0%|          | 0.00/14.5k [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:   0%|          | 0.00/608M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading pytorch_model.fp16.bin:   0%|          | 0.00/608M [00:00<?, ?B/s]
# Downloading (…)7f0/model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Downloading (…)cheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading model.fp16.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Downloading pytorch_model.fp16.bin:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)7f0/unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading (…)on_pytorch_model.bin:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)torch_model.fp16.bin:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading (…)-pruned-emaonly.ckpt:   0%|          | 0.00/4.27G [00:00<?, ?B/s]
# Downloading (…)-emaonly.safetensors:   0%|          | 0.00/4.27G [00:00<?, ?B/s]
# Downloading v1-5-pruned.ckpt:   0%|          | 0.00/7.70G [00:00<?, ?B/s]
# Downloading (…)5-pruned.safetensors:   0%|          | 0.00/7.70G [00:00<?, ?B/s]
# Downloading (…)f0/v1-inference.yaml:   0%|          | 0.00/1.87k [00:00<?, ?B/s]
# Downloading (…)57f0/vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading (…)on_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Downloading (…)torch_model.fp16.bin:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Downloading (…)del.fp16.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]

# %% [markdown]
# # Upload the user's image
#
# Images will be uploaded in a specific directory with only the user's pics

# %%
CLASS_DATA_DIR = "/content/data/person"
INSTANCE_DATA_DIR = "/content/data/ukj"

# %%
#just checking
# !echo $CLASS_DATA_DIR
# Out:
# /content/data/person

# %% [markdown]
# #To DO
#
# Need to add the function to resize the image to 512x512 using PIL from image

# %%
#markdown 🖼️ **Upload your images by running this cell.**
import json
import os
from google.colab import files
import shutil

# `class_data_dir` contains regularization images

os.makedirs(INSTANCE_DATA_DIR, exist_ok=True)
os.makedirs(CLASS_DATA_DIR, exist_ok=True)

uploaded = files.upload()
for filename in uploaded.keys():
    dst_path = os.path.join(INSTANCE_DATA_DIR, filename)
    shutil.move(filename, dst_path)

# %% [markdown]
# # Training the model
# TODO need to downaload the vae and set to local_files_only=True,
#
# 1. The path must be relative path - the code is in content and the path must be /content/stable_diffusion_weights
#
#
# 2. lr_warmup steps should be max_trainins steps divided by 10
#
# 3. num_class_images is the number of images it wll be generated within the class prompt you passed to the model (men, person,..etc)-> 200-300 good
#
#
# 4. model needs to be started with !/usr/bin/python3 train_dreambooth.py not with accelerate cos it doesnt work anymore
#
# 5. train batch size 4 (2 per gpu) for faces

# %%
#@title Model training
# !/usr/bin/python3 train_dreambooth.py \
  --pretrained_model_name_or_path="/content/stable_diffusion_weights" \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --instance_data_dir=$INSTANCE_DATA_DIR \
  --class_data_dir=$CLASS_DATA_DIR \
  --instance_prompt="photo of ukj person"\
  --class_prompt="photo of a person"\
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=120 \
  --num_class_images=200 \
  --sample_batch_size=4 \
  --max_train_steps=1200 \
  --class_prompt="photo of ukj alex"\
  --save_sample_negative_prompt="disfigured, bad skin, dark,ugly, bad, immature, cartoon, anime, 3d, painting, b&w, blur"\
  --save_interval=600 \
  --save_sample_prompt="photo of ukj alex"
# Out:
# 2023-08-20 20:18:40.286958: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading pipeline components...: 100% 6/6 [00:15<00:00,  2.52s/it]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 08/20/2023 20:19:09 - INFO - __main__ - Number of class images to sample: 200.
# Generating class images: 100% 50/50 [10:40<00:00, 12.80s/it]
# 08/20/2023 20:29:52 - WARNING - __main__ - xformers is not available. Make sure it is installed correctly
# /usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:239: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Caching latents: 100% 200/200 [00:38<00:00,  5.14it/s]
# 08/20/2023 20:30:47 - INFO - __main__ - ***** Running training *****
# 08/20/2023 20:30:47 - INFO - __main__ -   Num examples = 200
# 08/20/2023 20:30:47 - INFO - __main__ -   Num batches each epoch = 200
# 08/20/2023 20:30:47 - INFO - __main__ -   Num Epochs = 6
# 08/20/2023 20:30:47 - INFO - __main__ -   Instantaneous batch size per device = 1
# 08/20/2023 20:30:47 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 08/20/2023 20:30:47 - INFO - __main__ -   Gradient Accumulation steps = 1
# 08/20/2023 20:30:47 - INFO - __main__ -   Total optimization steps = 1200
# Steps:  50% 600/1200 [09:05<08:50,  1.13it/s, loss=0.28, lr=1e-6]
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 76.26it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:05<00:15,  5.25s/it]
# Generating samples:  50% 2/4 [00:08<00:08,  4.21s/it]
# Generating samples:  75% 3/4 [00:12<00:03,  3.87s/it]
# Generating samples: 100% 4/4 [00:15<00:00,  3.91s/it]
# [*] Weights saved at /content/./stable_diffusion_weights/600
# Steps: 100% 1200/1200 [19:25<00:00,  1.11it/s, loss=0.284, lr=1e-6]
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 53.61it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:03<00:10,  3.59s/it]
# Generating samples:  50% 2/4 [00:07<00:07,  3.53s/it]
# Generating samples:  75% 3/4 [00:10<00:03,  3.50s/it]
# Generating samples: 100% 4/4 [00:14<00:00,  3.51s/it]
# [*] Weights saved at /content/./stable_diffusion_weights/1200
# Steps: 100% 1200/1200 [20:33<00:00,  1.03s/it, loss=0.284, lr=1e-6]

# %% [markdown]
# # To DO
#
# Set another savng directory so the code works to get automatially the lastest version saved - model_path = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]

# %%
print(OUTPUT_DIR)
# Out:
# /content/./stable_diffusion_weights

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display
from natsort import natsorted
from glob import glob
import os
print(natsorted(glob(OUTPUT_DIR + os.sep + "*")))

model_path = '/content/./stable_diffusion_weights/1200'
print(model_path)

scheduler = DDIMScheduler(beta_start=0.00085, beta_end=0.012, beta_schedule="scaled_linear", clip_sample=False, set_alpha_to_one=False)
pipe = StableDiffusionPipeline.from_pretrained(model_path, scheduler=scheduler, safety_checker=None, torch_dtype=torch.float16).to("cuda")
g_cuda = torch.Generator(device='cuda')
# Out:
# ['/content/./stable_diffusion_weights/0', '/content/./stable_diffusion_weights/600', '/content/./stable_diffusion_weights/1200', '/content/./stable_diffusion_weights/README.md', '/content/./stable_diffusion_weights/feature_extractor', '/content/./stable_diffusion_weights/model_index.json', '/content/./stable_diffusion_weights/safety_checker', '/content/./stable_diffusion_weights/scheduler', '/content/./stable_diffusion_weights/text_encoder', '/content/./stable_diffusion_weights/tokenizer', '/content/./stable_diffusion_weights/unet', '/content/./stable_diffusion_weights/v1-5-pruned-emaonly.ckpt', '/content/./stable_diffusion_weights/v1-5-pruned-emaonly.safetensors', '/content/./stable_diffusion_weights/v1-5-pruned.ckpt', '/content/./stable_diffusion_weights/v1-5-pruned.safetensors', '/content/./stable_diffusion_weights/v1-inference.yaml', '/content/./stable_diffusion_weights/vae']
# /content/./stable_diffusion_weights/1200
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %% [markdown]
# # Inference
#
# Set some random seed for random reproductibality

# %%
#@markdown **Run for generating images.**

prompt = "close up photo of ukj person as a mermaid" #@param {type:"string"}
negative_prompt = ""
num_samples = 4 #@param {type:"number"}
guidance_scale = 7.5 #@param {type:"number"}
num_inference_steps = 100 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}
seed = 52362 #@param {type:"number"}

g_cuda.manual_seed(seed)

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt="disfigured, bad skin, dark,ugly, bad, immature, cartoon, anime, 3d, painting, b&w, blur",
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
